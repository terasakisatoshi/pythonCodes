# %% [markdown]
# # Calc Eigen Value

# %%
import numpy as np

# %%
a=np.array([[16,-1,1,2],
                        [2,12,1,-1],
                        [1,3,-24,2],
                        [4,-2,1,20]],dtype='f')
#initial value s.t. np.linang.norm(x) is 1
x=np.array([0.5,0.5,0.5,0.5]).T
x
# Out:
# array([ 0.5,  0.5,  0.5,  0.5])

# %%
epsilon=0.01
maxiteration=100

# %%
x_new=a @ x
eigen=x_new.dot(x)
x_new/=np.linalg.norm(x_new)

# %%
for iteration in range(maxiteration):
    x_new =a@x
    eigen=x_new.dot(x)
    if(np.linalg.norm(x_new-eigen*x)<epsilon):
        break
    #normalize
    x_new/=np.linalg.norm(x_new)
    #update x
    x=x_new
else:
    print("fail to calc eigen value")
    exit(1)
    
print("num of iteration is %d"%iteration)
print("one of eigen value of a is %f"%eigen)
print("its eigen vector is \n{}")
# Out:
# num of iteration is 0
# one of eigen value of a is -24.148327
# its eigen vector is
# [-0.0244012  -0.0268873   0.99911089 -0.02142602]

# %% [markdown]
# # final code is...

# %%
import numpy as np

a=np.array([[16,-1,1,2],
                        [2,12,1,-1],
                        [1,3,-24,2],
                        [4,-2,1,20]],dtype='f')
#initial value s.t. np.linang.norm(x) is 1
x=np.array([0.5,0.5,0.5,0.5]).T
epsilon=0.01
maxiteration=100
for iteration in range(maxiteration):
    x_new =a@x
    eigen=x_new.dot(x)
    if(np.linalg.norm(x_new-eigen*x)<epsilon):
        break
    #normalize
    x_new/=np.linalg.norm(x_new)
    #update x
    x=x_new
else:
    print("fail to calc eigen value")
    exit(1)
    
print("num of iteration is %d"%iteration)
print("one of eigen value of a is %f"%eigen)
print("its eigen vector is \n{}".format(x))
# Out:
# num of iteration is 78
# one of eigen value of a is -24.148327
# its eigen vector is
# [-0.0244012  -0.0268873   0.99911089 -0.02142602]

# %%
import sympy as sy
sy.init_printing()
sy_a=sy.Matrix(a)
sy_a
# Out:
# ⎡16.0  -1.0   1.0   2.0 ⎤
# ⎢                       ⎥
# ⎢2.0   12.0   1.0   -1.0⎥
# ⎢                       ⎥
# ⎢1.0   3.0   -24.0  2.0 ⎥
# ⎢                       ⎥
# ⎣4.0   -2.0   1.0   20.0⎦

# %%
sy_a.eigenvals()
# Out:
# ⎧
# ⎪
# ⎪
# ⎪
# ⎪            _________________________________________________________________
# ⎪           ╱                                                  _______________
# ⎪          ╱                      17344                       ╱           4⋅√6
# ⎨         ╱   420 + ────────────────────────────────── + 2⋅3 ╱  -109940 + ────
# ⎪        ╱                ____________________________     ╲╱
# ⎪       ╱                ╱           4⋅√61091584359⋅ⅈ
# ⎪      ╱            3⋅3 ╱  -109940 + ────────────────
# ⎪    ╲╱               ╲╱                    9
# ⎪6 - ─────────────────────────────────────────────────────────────────────────
# ⎪                                               2
# ⎩
#
#                              _________________________________________________
#                             ╱             ____________________________
#                            ╱             ╱           4⋅√61091584359⋅ⅈ
#                           ╱   840 - 2⋅3 ╱  -109940 + ────────────────  + ─────
# ______________           ╱            ╲╱                    9
# _____________           ╱
# 1091584359⋅ⅈ           ╱
# ────────────          ╱
#    9                 ╱                                                       ╱
#                     ╱                                                       ╱
#                    ╱                                                       ╱
#                  ╲╱                                                      ╲╱
# ────────────── - ─────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#                                     15200
# ──────────────────────────────────────────────────────────────────────────────
#    ___________________________________________________________________________
#   ╱                                                  _________________________
#  ╱                      17344                       ╱           4⋅√61091584359
# ╱   420 + ────────────────────────────────── + 2⋅3 ╱  -109940 + ──────────────
#                 ____________________________     ╲╱                    9
#                ╱           4⋅√61091584359⋅ⅈ
#           3⋅3 ╱  -109940 + ────────────────
#             ╲╱                    9
# ──────────────────────────────────────────────────────────────────────────────
#                              2
#
#
# __________________________________________
#
#                      17344
# ──── - ──────────────────────────────────
# ____         ____________________________                  ___________________
# ___         ╱           4⋅√61091584359⋅ⅈ                  ╱
# ⋅ⅈ     3⋅3 ╱  -109940 + ────────────────                 ╱
# ──       ╲╱                    9                        ╱   420 + ────────────
#                                                        ╱                ______
#                                                       ╱                ╱
#                                                      ╱            3⋅3 ╱  -1099
#                                                    ╲╱               ╲╱
# ──────────────────────────────────────────: 1, 6 - ───────────────────────────
#
#
#
#                                                                            ___
#                                                                           ╱
#                                                                          ╱
#                                                                         ╱   84
# ____________________________________________________________           ╱
#                                ____________________________           ╱
#   17344                       ╱           4⋅√61091584359⋅ⅈ           ╱
# ────────────────────── + 2⋅3 ╱  -109940 + ────────────────          ╱
# ______________________     ╲╱                    9                 ╱
#      4⋅√61091584359⋅ⅈ                                             ╱
# 40 + ────────────────                                            ╱
#             9                                                  ╲╱
# ──────────────────────────────────────────────────────────── + ───────────────
#                 2
#
#
# ______________________________________________________________________________
#           ____________________________
#          ╱           4⋅√61091584359⋅ⅈ
# 0 - 2⋅3 ╱  -109940 + ────────────────  + ─────────────────────────────────────
#       ╲╱                    9                    _____________________________
#                                                 ╱
#                                                ╱                      17344
#                                               ╱   420 + ──────────────────────
#                                              ╱                ________________
#                                             ╱                ╱           4⋅√61
#                                            ╱            3⋅3 ╱  -109940 + ─────
#                                          ╲╱               ╲╱
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            2
#
#
# ______________________________________________________________________________
#
#     15200                                                          17344
# ────────────────────────────────────────────────── - ─────────────────────────
# __________________________________________________         ___________________
#                      ____________________________         ╱           4⋅√61091
#                     ╱           4⋅√61091584359⋅ⅈ     3⋅3 ╱  -109940 + ────────
# ──────────── + 2⋅3 ╱  -109940 + ────────────────       ╲╱                    9
# ____________     ╲╱                    9
# 091584359⋅ⅈ
# ───────────
#   9
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# __________
#
#
# ─────────
# _________                  ___________________________________________________
# 584359⋅ⅈ                  ╱                                                  _
# ────────                 ╱                      17344                       ╱
#                         ╱   420 + ────────────────────────────────── + 2⋅3 ╱
#                        ╱                ____________________________     ╲╱
#                       ╱                ╱           4⋅√61091584359⋅ⅈ
#                      ╱            3⋅3 ╱  -109940 + ────────────────
#                    ╲╱               ╲╱                    9
# ──────────: 1, 6 + ───────────────────────────────────────────────────────────
#                                                               2
#
#
#                                            ___________________________________
#                                           ╱             ______________________
#                                          ╱             ╱           4⋅√61091584
#                                         ╱   840 - 2⋅3 ╱  -109940 + ───────────
# ____________________________           ╱            ╲╱                    9
# ___________________________           ╱
#           4⋅√61091584359⋅ⅈ           ╱
# -109940 + ────────────────          ╱
#                  9                 ╱
#                                   ╱
#                                  ╱
#                                ╲╱
# ──────────────────────────── - ───────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
# ______
# 359⋅ⅈ                                             15200
# ─────  - ─────────────────────────────────────────────────────────────────────
#                  _____________________________________________________________
#                 ╱                                                  ___________
#                ╱                      17344                       ╱
#               ╱   420 + ────────────────────────────────── + 2⋅3 ╱  -109940 +
#              ╱                ____________________________     ╲╱
#             ╱                ╱           4⋅√61091584359⋅ⅈ
#            ╱            3⋅3 ╱  -109940 + ────────────────
#          ╲╱               ╲╱                    9
# ──────────────────────────────────────────────────────────────────────────────
#                                            2
#
#
# ________________________________________________________                     _
#                                                                             ╱
#                                    17344                                   ╱
# ────────────────── - ──────────────────────────────────                   ╱
# __________________         ____________________________                  ╱
# _________________         ╱           4⋅√61091584359⋅ⅈ                  ╱
# 4⋅√61091584359⋅ⅈ     3⋅3 ╱  -109940 + ────────────────                 ╱
# ────────────────       ╲╱                    9                        ╱
#        9                                                             ╱
#                                                                     ╱
#                                                                    ╱
#                                                                  ╲╱
# ────────────────────────────────────────────────────────: 1, 6 + ─────────────
#
#
#
# ______________________________________________________________________________
#             ____________________________
#            ╱           4⋅√61091584359⋅ⅈ
# 840 - 2⋅3 ╱  -109940 + ────────────────  - ───────────────────────────────────
#         ╲╱                    9                    ___________________________
#                                                   ╱
#                                                  ╱                      17344
#                                                 ╱   420 + ────────────────────
#                                                ╱                ______________
#                                               ╱                ╱           4⋅√
#                                              ╱            3⋅3 ╱  -109940 + ───
#                                            ╲╱               ╲╱
# ──────────────────────────────────────────────────────────────────────────────
#                                                                              2
#
#
# ______________________________________________________________________________
#
#       15200                                                          17344
# ──────────────────────────────────────────────────── - ───────────────────────
# ____________________________________________________         _________________
#                        ____________________________         ╱           4⋅√610
#                       ╱           4⋅√61091584359⋅ⅈ     3⋅3 ╱  -109940 + ──────
# ────────────── + 2⋅3 ╱  -109940 + ────────────────       ╲╱
# ______________     ╲╱                    9
# 61091584359⋅ⅈ
# ─────────────
#     9
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ____________
#
#
# ───────────
# ___________            _______________________________________________________
# 91584359⋅ⅈ            ╱                                                  _____
# ──────────           ╱                      17344                       ╱
#  9                  ╱   420 + ────────────────────────────────── + 2⋅3 ╱  -109
#                    ╱                ____________________________     ╲╱
#                   ╱                ╱           4⋅√61091584359⋅ⅈ
#                  ╱            3⋅3 ╱  -109940 + ────────────────
#                ╲╱               ╲╱                    9
# ──────────── + ───────────────────────────────────────────────────────────────
#                                                           2
#
#
#                            ⎫
#                            ⎪
#                            ⎪
#                            ⎪
# ________________________   ⎪
# _______________________    ⎪
#       4⋅√61091584359⋅ⅈ     ⎪
# 940 + ────────────────     ⎬
#              9             ⎪
#                            ⎪
#                            ⎪
#                            ⎪
# ────────────────────────: 1⎪
#                            ⎪
#                            ⎭

# %%
sy_a.eigenvects()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-93-4e0d55d21221> in <module>()
# ----> 1 sy_a.eigenvects()
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/matrices/matrices.py in eigenvects(self, **flags)
#    3085         for r, k in vlist:
#    3086             tmp = mat.as_mutable() - eye(mat.rows)*r
# -> 3087             basis = tmp.nullspace()
#    3088             # whether tmp.is_symbolic() is True or False, it is possible that
#    3089             # the basis will come back as [] in which case simplification is
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/matrices/matrices.py in nullspace(self, simplify)
#    2784         simpfunc = simplify if isinstance(
#    2785             simplify, FunctionType) else _simplify
# -> 2786         reduced, pivots = self.rref(simplify=simpfunc)
#    2787
#    2788         basis = []
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/matrices/matrices.py in rref(self, iszerofunc, simplify)
#    2718                 break
#    2719             if simplify:
# -> 2720                 r[pivot, i] = simpfunc(r[pivot, i])
#    2721             if iszerofunc(r[pivot, i]):
#    2722                 for k in range(pivot, r.rows):
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, fu)
#     598     numer, denom = expr.as_numer_denom()
#     599     if denom.is_Add:
# --> 600         n, d = fraction(radsimp(1/denom, symbolic=False, max_terms=1))
#     601         if n is not S.One:
#     602             expr = (numer*n).expand()/d
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/simplify/radsimp.py in radsimp(expr, symbolic, max_terms)
#     856     expr = expr.normal()
#     857     old = fraction(expr)
# --> 858     n, d = fraction(handle(expr))
#     859     if old != (n, d):
#     860         if not d.is_Atom:
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/simplify/radsimp.py in handle(expr)
#     797         # is it a number that might be handled easily?
#     798         if d.is_number:
# --> 799             _d = nsimplify(d)
#     800             if _d.is_Number and _d.equals(d):
#     801                 return 1/_d
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/simplify/simplify.py in nsimplify(expr, constants, tolerance, full, rational)
#    1130     """
#    1131     try:
# -> 1132         return sympify(as_int(expr))
#    1133     except (TypeError, ValueError):
#    1134         pass
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/compatibility.py in as_int(n)
#     400     """
#     401     try:
# --> 402         result = int(n)
#     403         if result != n:
#     404             raise TypeError
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in __int__(self)
#     193         # places) we need to test whether we are off by one.
#     194         from sympy import Dummy
# --> 195         r = self.round(2)
#     196         if not r.is_Number:
#     197             raise TypeError("can't convert complex to int")
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# ... last 7 frames repeated, from the frame below ...
#
# /Users/terasakisatoshi/.pyenv/versions/3.5.1/lib/python3.5/site-packages/sympy/core/expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# RecursionError: maximum recursion depth exceeded

# %%
from scipy import linalg as sla

# %%
sla.eigvals(a)
# Out:
# array([-24.14852524+0.j,  21.57934570+0.j,  12.23095798+0.j,
#         14.33821487+0.j], dtype=complex64)

# %%
sla.eigvalsh(a)
# Out:
# array([-24.29197502,  10.03090763,  15.71542454,  22.54564667], dtype=float32)

# %%
sla.eig(a)
# Out:
# (array([-24.14852524+0.j,  21.57934570+0.j,  12.23095798+0.j,
#          14.33821487+0.j], dtype=complex64),
#  array([[ 0.02447723, -0.34770194, -0.14668337,  0.67053527],
#         [ 0.02688304,  0.02018997, -0.97126281,  0.70048612],
#         [-0.99910468, -0.04737921, -0.09344059,  0.05994677],
#         [ 0.02163069, -0.93618959, -0.16248505, -0.23687127]], dtype=float32))
