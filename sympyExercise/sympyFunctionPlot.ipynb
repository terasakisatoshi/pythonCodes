# %%
from sympy import symbols
from sympy.plotting import plot
x=symbols('x')
p1=plot(x*x)
p2=plot(x)
p1.append(p2[0])
p1

# %%
x=symbols('x')
p1=plot(x*x)
p2=plot(x)
p1.extend(p2)
p1

# %%
plot(x, x**2, x**3, (x, -5, 5))

# %%
from sympy.geometry import *
t = RegularPolygon(Point(0,0), 1, 5)

# %%
from sympy.plotting.plot import Plot
p=Plot(axes='label_axes=True')
for i in range(len(t.sides)):
    p[i]=t.sides[i]
p.show
# Out:
# <bound method Plot.show of <sympy.plotting.plot.Plot object at 0x000002270C9A2FD0>>
