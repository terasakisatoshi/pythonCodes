# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
xs=np.linspace(0,2*np.pi,100)
ys=np.sin(xs)

# %%
#subplots は一回の関数の呼び出しでFigureとAxesインスタンスを生成する．

# %%
fig,ax=plt.subplots()
ax.plot(xs,ys)
ax.plot(xs,2*ys)

# %% [markdown]
# # グラフの種類
#
# matplotlib には Axesインスタンスメソッドとして，さまざまな種類のグラフの作成機能が実装されている．

# %%
N=15
xs=np.linspace(0,2*np.pi,N)
ys=np.sin(xs)
ys_err=0.5*np.random.rand(N)
fig,ax=plt.subplots(2,2,figsize=(8,4),sharey=True)
ax[0][0].step(xs,ys)
ax[0][1].errorbar(xs,ys,yerr=ys_err,fmt='o')
ax[1][0].fill(xs,ys)
ax[1][1].bar(xs,ys,0.2)
# Out:
# <BarContainer object of 15 artists>

# %%
import matplotlib 
matplotlib.style.use('ggplot')
N=50
xs=np.random.rand(N)
ys=np.random.rand(N)
z=np.sqrt(xs**2+ys**2)

fig,ax=plt.subplots()
ax.scatter(xs,ys,s=80,c=z)

# %% [markdown]
# # グラフの一部を拡大

# %%
xs=np.linspace(0,2*np.pi,100)
ys=np.sin(xs)

fig,ax=plt.subplots(subplot_kw=dict(axisbg='#eeeeff'))
ax.plot(xs,ys)

axins=fig.add_axes([0.55,0.55,0.3,0.3],axisbg='none')
axins.plot(-xs,ys)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d919309e782e> in <module>()
#       2 ys=np.sin(xs)
#       3
# ----> 4 fig,ax=plt.subplots(subplot_kw=dict(axisbg='#eeeeff'))
#       5 ax.plot(xs,ys)
#       6
#
# ~/.pyenv/versions/miniconda3-3.19.0/lib/python3.5/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1199     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1200                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1201                        gridspec_kw=gridspec_kw)
#    1202     return fig, axs
#    1203
#
# ~/.pyenv/versions/miniconda3-3.19.0/lib/python3.5/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
# ...

# %% [markdown]
# from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
# from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
n=200
xs=np.linspace(0,2*np.pi,n)
ys=np.cos(2*np.pi*xs) * np.exp(-xs) + 0.1 * np.random.rand(n)
fig,ax=plt.subplots(subplot_kw=dict(axisbg='#eeeeff'))
ax.plot(xs,ys)

#拡大図を生成
axins=zoomed_inset_axes(ax,4,loc=9,axes_kwargs=dict(axisbg='none'))
axins.plot(xs,ys)
x1,x2,y1,y2=0.7,1.3,0.3,0.5
axins.set_xlim(x1,x2)
axins.set_ylim(y1,y2)
#拡大図のメモリのラベルを非表示
axins.set_xticklabels([])
axins.set_yticklabels([])
mark_inset(ax,axins,loc1=2,loc2=4,fc='none',ec='0.5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-74c326769eed> in <module>()
#       2 xs=np.linspace(0,2*np.pi,n)
#       3 ys=np.cos(2*np.pi*xs) * np.exp(-xs) + 0.1 * np.random.rand(n)
# ----> 4 fig,ax=plt.subplots(subplot_kw=dict(axisbg='#eeeeff'))
#       5 ax.plot(xs,ys)
#       6
#
# ~/.pyenv/versions/miniconda3-3.19.0/lib/python3.5/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1199     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1200                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1201                        gridspec_kw=gridspec_kw)
#    1202     return fig, axs
#    1203
#
# ...
